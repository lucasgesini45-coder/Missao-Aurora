# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasgesini45-coder/Missao-Aurora/blob/main/Codigo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #importaçao das classes
# import random
#
# import time
#
# import pandas as pd

# %% [markdown]
# #Fase Inicial Da Missao.
# print("==================================\n       MISSAO AURORA SIGER\n==================================")
#
# resposta = input("Deseja iniciar o processo para lançamento do Foguete? sim/nao ").strip().lower()
#
# time.time()
#
# if resposta == "sim":
#     print("iniciando processo de verificaçao\nAveriguando dados..")
#     time.sleep(1.5)
#
#     print("Verificando Temperatura Externa...")
#     time.sleep(0.5)
#
#     print("Verificando Temperatura Interna..")
#     time.sleep(0.6)
#
#     print("Verificando Energia do tanque....")
#     time.sleep(0.8)
#
#     print("Verificando Pressao Do Tanque..")
#     time.sleep(0.2)
#
#     print("Verificando Integridade Estrutural...")
#     time.sleep(0.6)
#
#     print(f"Verificando Modulos Criticos..")
#     time.sleep(0.4)
# elif resposta == "nao":
#     print("O lançamento foi cancelado!")
#     exit()
# else:
#     print("Resposta invalida!")
#     exit()

# %% [markdown]
# #Declaraçao de variaveis
#
# temp_externa = [15, 30]
#
# temp_interna = [15, 40]
#
# energia = [28, 32]
#
# pressao_tanque = [2, 5]
#
# integridade_estrutural = [95, 100]
#
# modulos_criticos = [ 0,1]

# %% [markdown]
# #Utilizaçao do random para escolher numeros aleatorios conforme os dados.
#
# temp_externa1 = random.choice (temp_externa)
#
# temp_interna2 = random.choice (temp_interna)
#
# energia3 = random.choice (energia)
#
# pressao_tanque4 = random.choice (pressao_tanque)
#
# integridade_estrutural5 = random.choice (integridade_estrutural)
#
# modulos_criticos6 = random.choice (modulos_criticos)

# %% [markdown]
# #Tabela final de telemetria
#
# print("\n=================================================")
#
# print("                DADOS DO FOGUETE 🚀")
#
# print("=================================================")
#
# print(f"{'Parametro':25} | {'Valor':7} | Status")
#
# print("-------------------------------------------------")
#
# status_temp_ext = "OK" if temp_externa1 >= 15 else "N/G"
#
# status_temp_int = "OK" if temp_interna2 >= 20 else "N/G"
#
# status_energia = "OK" if energia3 >= 30 else "N/G"
#
# status_pressao = "OK" if pressao_tanque4 >= 3 else "N/G"
#
# status_integridade = "OK" if integridade_estrutural5 == 1 else "N/G"
#
# status_modulos = "OK" if modulos_criticos6 == 1 else "N/G"
#
# print(f"{'Temp Externa°C':25} | {temp_externa1:<7} | {status_temp_ext}")
#
# print(f"{'Temp Interna°C':25} | {temp_interna2:<7} | {status_temp_int}")
#
# print(f"{'Energia':25} | {energia3:<7} | {status_energia}")
#
# print(f"{'Pressao Tanque':25} | {pressao_tanque4:<7} | {status_pressao}")
#
# print(f"{'Integridade Estrutural':25} | {integridade_estrutural5:<7} | {status_integridade}")
#
# print(f"{'Modulos Criticos':25} | {modulos_criticos6:<7} | {status_modulos}")
#
# print("=================================================")

# %% [markdown]
# # ANÁLISE ENERGÉTICA
#
# print("\n⚡ ANÁLISE ENERGÉTICA")
#
# print("=================================================")
#
# capacidade_total = random.randint(800, 1200)  # kWh
#
# carga_percentual = random.randint(60, 100)  # %
#
# consumo_decolagem = random.randint(200, 400)  # kWh
#
# perdas = random.uniform(0.05, 0.15)  # %
#
# energia_disponivel = capacidade_total * (carga_percentual / 100) * (1 - perdas)
#
# autonomia = energia_disponivel / consumo_decolagem
#
# print(f"Capacidade Total: {capacidade_total} kWh")
#
# print(f"Carga Atual: {carga_percentual}%")
#
# print(f"Perdas Energéticas: {perdas * 100:.1f}%")
#
# print(f"Energia Disponível: {energia_disponivel:.2f} kWh")
#
# print(f"Consumo na Decolagem: {consumo_decolagem} kWh")
#
# print(f"Autonomia Estimada: {autonomia:.2f} ciclos")
#
# if autonomia >= 1:
#
#     status_energia_geral = "OK"
#
#     print("✅ Energia suficiente para decolagem")
#
# else:
#
#     status_energia_geral = "CRITICO"
#
#     print("❌ Energia insuficiente")
#
# print("=================================================")

# %% [markdown]
# #se todos os dados estiverem ok Decolagem autorizada
#
# if (temp_externa1 >= 115 and
#
#     temp_interna2 >= 25 and
#
#     energia3 >= 6 and
#
#     pressao_tanque4 >= 99 and
#
#     integridade_estrutural5 == 1 and
#
#     modulos_criticos6 == 1):
#
#     print("""
# Foguete autorizado para a decolagem!
#
# Iniciando Decolagem!
#
# """)
#
# else:
#     print("\n❌ Decolagem nao autorizada!")
#
#     print("Status da nave nao esta dentro dos parametros.")

# %%
#importaçao das classes
import random
import time
import pandas as pd
#------------------------------------------------------------------------------------------
#Fase Inicial Da Missao.
print("==================================\n       MISSAO AURORA SIGER\n==================================")
resposta = input("Deseja iniciar o processo para lançamento do Foguete? sim/nao ").strip().lower()
time.time()

if resposta == "sim":
    print("iniciando processo de verificaçao\nAveriguando dados..")
    time.sleep(1.5)

    print("Verificando Temperatura Externa...")
    time.sleep(0.5)

    print("Verificando Temperatura Interna..")
    time.sleep(0.6)

    print("Verificando Energia do tanque....")
    time.sleep(0.8)

    print("Verificando Pressao Do Tanque..")
    time.sleep(0.2)

    print("Verificando Integridade Estrutural...")
    time.sleep(0.6)

    print(f"Verificando Modulos Criticos..")
    time.sleep(0.4)
elif resposta == "nao":
    print("O lançamento foi cancelado!")
    exit()
else:
    print("Resposta invalida!")
    exit()

#-------------------------------------------------------------------------------------------
#Declaraçao de variaveis

temp_externa = [15, 30]
temp_interna = [15, 40]
energia = [28, 32]
pressao_tanque = [2, 5]
integridade_estrutural = [95, 100]
modulos_criticos = [ 0,1]

#-------------------------------------------------------------------------------------------
#Utilizaçao do random para escolher numeros aleatorios conforme os dados.

temp_externa1 = random.choice (temp_externa)
temp_interna2 = random.choice (temp_interna)
energia3 = random.choice (energia)
pressao_tanque4 = random.choice (pressao_tanque)
integridade_estrutural5 = random.choice (integridade_estrutural)
modulos_criticos6 = random.choice (modulos_criticos)


#-------------------------------------------------------------------------------------------
#Tabela final de telemetria

print("\n=================================================")
print("                DADOS DO FOGUETE 🚀")
print("=================================================")
print(f"{'Parametro':25} | {'Valor':7} | Status")
print("-------------------------------------------------")

status_temp_ext = "OK" if temp_externa1 >= 15 else "N/G"
status_temp_int = "OK" if temp_interna2 >= 20 else "N/G"
status_energia = "OK" if energia3 >= 30 else "N/G"
status_pressao = "OK" if pressao_tanque4 >= 3 else "N/G"
status_integridade = "OK" if integridade_estrutural5 == 1 else "N/G"
status_modulos = "OK" if modulos_criticos6 == 1 else "N/G"

print(f"{'Temp Externa°C':25} | {temp_externa1:<7} | {status_temp_ext}")
print(f"{'Temp Interna°C':25} | {temp_interna2:<7} | {status_temp_int}")
print(f"{'Energia':25} | {energia3:<7} | {status_energia}")
print(f"{'Pressao Tanque':25} | {pressao_tanque4:<7} | {status_pressao}")
print(f"{'Integridade Estrutural':25} | {integridade_estrutural5:<7} | {status_integridade}")
print(f"{'Modulos Criticos':25} | {modulos_criticos6:<7} | {status_modulos}")

print("=================================================")

# ANÁLISE ENERGÉTICA

print("\n⚡ ANÁLISE ENERGÉTICA")
print("=================================================")

capacidade_total = random.randint(800, 1200)  # kWh
carga_percentual = random.randint(60, 100)  # %
consumo_decolagem = random.randint(200, 400)  # kWh
perdas = random.uniform(0.05, 0.15)  # %

energia_disponivel = capacidade_total * (carga_percentual / 100) * (1 - perdas)
autonomia = energia_disponivel / consumo_decolagem

print(f"Capacidade Total: {capacidade_total} kWh")
print(f"Carga Atual: {carga_percentual}%")
print(f"Perdas Energéticas: {perdas * 100:.1f}%")
print(f"Energia Disponível: {energia_disponivel:.2f} kWh")
print(f"Consumo na Decolagem: {consumo_decolagem} kWh")
print(f"Autonomia Estimada: {autonomia:.2f} ciclos")

if autonomia >= 1:
    status_energia_geral = "OK"
    print("✅ Energia suficiente para decolagem")
else:
    status_energia_geral = "CRITICO"
    print("❌ Energia insuficiente")

print("=================================================")
#-------------------------------------------------------------------------------------------
#se todos os dados estiverem ok Decolagem autorizada

if (temp_externa1 >= 115 and
    temp_interna2 >= 25 and
    energia3 >= 6 and
    pressao_tanque4 >= 99 and
    integridade_estrutural5 == 1 and
    modulos_criticos6 == 1):

    print("""
Foguete autorizado para a decolagem!
Iniciando Decolagem!

""")

else:
    print("\n❌ Decolagem nao autorizada!")
    print("Status da nave nao esta dentro dos parametros.")
